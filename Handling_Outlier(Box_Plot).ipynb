# %% [markdown]
# # Box PLot and 5 Number summary

# %%
sample_dataset= [-124,34,5,6,78,45,89,76,41,32,9,4,34,59,72,88,41,26,83,43,75,90,56,3,7,58,6,0,33,80,67,87,43,-2,-54,-32,-76,180]
import numpy as np
minimum,Q1,median,Q3,maximum=np.quantile(sample_dataset,q=[0,0.25,0.50,0.75,1.0])

# %%
#Calculating interquartile range IQR
IQR=Q3-Q1
print(IQR)
#Calculate the lower and upper fence: Decider of the outliers on both the side
lower_fence=Q1-1.5*(IQR)
upper_fence=Q3+1.5*(IQR)
print(lower_fence)
print(upper_fence)
print(Q3)
# Out:
# 68.25
# -96.375
# 176.625
# 74.25

# %%
import seaborn as sns
sns.boxplot(sample_dataset)
# Out:
# <Axes: >
